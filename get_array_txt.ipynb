# %%
import numpy as np
from rake_nltk import Rake
import nltk
nltk.download('stopwords')
import os
import googletrans
from googletrans import Translator



LANGUAGES = ['pt','fr','de','hi','it','ja','es','id']
translator = Translator()


#IMPORTANT!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
ALLOW_CREATION = False
PROJECT_NAME = 'tips_warren'

obj_r = {
    "couldn´t": "could not",
    "I'm": "I am",
    "I'll": "I will",
    "can't": "cannot",
    "It's": "It is",
    "We're": "We are",
    "we're": "we are",
    "we'll": 'we will',
    "you're": "you are"
}

banned_words = ["shadowy"]

replace_words = [
    ['"',""],
    ['’',"'"],
    ["!","."],
    [":","."],
    [" - ",", "]
]

def replace_text(str_input,obt_replace):
    
    for key in obt_replace:        
        str_input = str_input.replace(key,obt_replace[key])
    return str_input

def read_txt(txt):
    text_splited = []
    for y in replace_words:
            txt = txt.replace(y[0], y[1])
    """ txt = txt.replace("!",".")
    txt = txt.replace(":",".") # verify after """
    text_split = " ".join(txt.split()).split(".")
    first = text_split[0]
    temp_str = ""    
    
    for i in reversed(text_split):

        
                
        if i == first:            
            text_splited.append(replace_text(i + temp_str,obj_r) + ".")
        elif(i != " " and i != ""):            
            if(i[0].startswith(" ")):
                temp = i + temp_str + "."
                temp = temp[1:]       
                text_splited.append(replace_text(temp,obj_r))
                temp_str = ""
            else:                
                temp_str = i + temp_str 
    return reversed(text_splited)



txt = """I was cleaning out my late grandmother's attic after her passing, sorting through old trinkets and memories. As I rummaged through dusty boxes, I stumbled upon a small, antique doll hidden in the corner. It had porcelain skin, curly golden hair, and big blue eyes that seemed to stare right through me. Despite the storm outside, a chill ran down my spine as I picked it up.

As soon as I touched the doll, I felt a strange sensation, as if someone was watching me. I quickly brushed it off as my imagination playing tricks on me and placed the doll on a shelf in my bedroom. But as the night went on, I couldn't shake off the feeling of being watched.

That night, I woke up to strange noises coming from my bedroom. I tiptoed towards the source of the sound, and my heart skipped a beat when I saw the doll sitting on the floor, its eyes wide open. I was sure I had left it on the shelf. I picked it up and placed it back, convinced that it must have fallen off accidentally.

The following day, things started to get even more eerie. I noticed the doll had moved again, this time to the foot of my bed. I couldn't explain how it got there, and I started to feel a sense of unease every time I looked at it. The storm outside continued to rage, adding to the ominous atmosphere in the house.

As the days went by, the doll's movements became more frequent and unpredictable. It would be in the living room one moment and in the hallway the next. I started to feel paranoid, convinced that I was being watched by the doll. I couldn't shake off the feeling that something was off about it.

One night, I woke up to the sound of giggling coming from my bedroom. I slowly opened my eyes, and my heart stopped when I saw the doll standing at the foot of my bed, swaying back and forth. Its eyes seemed to be glowing in the darkness, and it had an eerie smile on its face. I was petrified, unable to move or make a sound. I blinked, and the doll was gone.

I decided to confide in a friend, who suggested that I get rid of the doll. But every time I tried to dispose of it, it would mysteriously reappear in my house. It was as if the doll was determined to stay with me, and its presence was becoming increasingly malevolent.

My once peaceful home had turned into a nightmare. I would hear footsteps in the middle of the night, and objects would move on their own. I would find the doll in unexpected places, staring at me with its unblinking eyes. I became sleep-deprived and paranoid, afraid to be alone in my own home.

One night, during another stormy evening, I decided to confront the doll once and for all. I grabbed it with trembling hands and took it outside, determined to get rid of it for good. But as I was about to throw it into a nearby lake, the doll suddenly came alive in my arms. It laughed hysterically, its eyes glowing brighter than ever.

In a panic, I dropped the doll and ran back to my house, slamming the door shut behind me. But the doll wasn't done with me yet. It kept appearing and disappearing, taunting me with its eerie presence. I couldn't take it anymore.

Desperate, I sought help from a paranormal expert who came to investigate my home. But as soon as he laid eyes on the doll, he gasped and took a step back. He told me that the doll was cursed, possessed by a vengeful spirit.

The paranormal expert warned me that the spirit attached to the doll was malevolent and had no intention of leaving. He explained that the doll had a dark history, having been used in occult rituals by a previous owner who had dabbled in black magic. The spirit had latched onto the doll and was now seeking revenge.

The expert performed a cleansing ritual, trying to banish the spirit from the doll, but the doll remained unresponsive. The atmosphere in my home grew even more sinister, with doors slamming shut, lights flickering, and eerie whispers echoing through the halls. I was living in constant fear, feeling the doll's malevolent presence lurking around every corner.

One fateful night, I woke up to the sound of scratching coming from my bedroom door. I mustered up my courage and slowly opened the door, only to find the doll sitting in the middle of the room, its eyes glowing with an otherworldly intensity. I tried to ignore the fear that gripped my heart and mustered up the strength to confront the doll.

"What do you want from me?" I demanded, my voice shaky.

The doll's expression twisted into a sinister grin as it spoke in a voice that was not its own. "You cannot escape me," it hissed, sending chills down my spine. "I will never leave."

In a fit of terror, I grabbed the doll and ran out of the house, determined to rid myself of its haunting presence once and for all. I drove for hours until I reached a remote cliff overlooking the ocean. With tears streaming down my face, I threw the doll into the crashing waves below, watching as it disappeared into the dark waters.

But as I turned to leave, I heard laughter echoing in the wind. I looked back to see the doll, somehow standing on the cliff, staring at me with its glowing eyes. My blood turned to ice as I realized that the spirit had not been banished, and the doll had returned to torment me once again.

In a state of sheer panic, I fled from the cliff and never looked back. I moved far away, hoping to escape the doll's grasp, but it seemed to always find its way back to me. The doll's haunting presence continued to torment me in my dreams, and I lived in perpetual fear, always looking over my shoulder, wondering when it would appear next.

To this day, I am still plagued by the doll's malevolent spirit. I have tried everything to rid myself of its presence, but it seems that nothing can break its hold on me. The doll's laughter still echoes in my nightmares, a constant reminder of the horror that I experienced. I have come to accept that the doll is now a part of my life, an ever-present reminder of the real-life horror story that unfolded after I found that haunted doll in my grandmother's attic.
"""


# Creating an instance
r = Rake()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Matheus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
def split_text_to_dict(text):
    lines = filter(None, re.split(r'(?<=[.!?])\s', text))  # Split text using regular expression to match dots, exclamation marks, and question marks followed by whitespace, and filter out empty lines
    result = {}
    for i, line in enumerate(lines):
        result[str(i)] = line.strip()  # Add line to the dictionary with the key as the line number and the value as the line text
    result.pop(str(len(result)-1), None)  # Remove the last item from the dictionary
    return result

output = split_text_to_dict(txt)

print(output)
# Out:
# {'0': "I was cleaning out my late grandmother's attic after her passing, sorting through old trinkets and memories.", '1': 'As I rummaged through dusty boxes, I stumbled upon a small, antique doll hidden in the corner.', '2': 'It had porcelain skin, curly golden hair, and big blue eyes that seemed to stare right through me.', '3': 'Despite the storm outside, a chill ran down my spine as I picked it up.', '4': 'As soon as I touched the doll, I felt a strange sensation, as if someone was watching me.', '5': 'I quickly brushed it off as my imagination playing tricks on me and placed the doll on a shelf in my bedroom.', '6': "But as the night went on, I couldn't shake off the feeling of being watched.", '7': 'That night, I woke up to strange noises coming from my bedroom.', '8': 'I tiptoed towards the source of the sound, and my heart skipped a beat when I saw the doll sitting on the floor, its eyes wide open.', '9': 'I was sure I had left it on the shelf.', '10': 'I picked it up and placed it back, convinced that it must have fallen off accidentally.', '11': 'The following day, things started to get even more eerie.', '12': 'I noticed the doll had moved again, this time to the foot of my bed.', '13': "I couldn't explain how it got there, and I started to feel a sense of unease every time I looked at it.", '14': 'The storm outside continued to rage, adding to the ominous atmosphere in the house.', '15': "As the days went by, the doll's movements became more frequent and unpredictable.", '16': 'It would be in the living room one moment and in the hallway the next.', '17': 'I started to feel paranoid, convinced that I was being watched by the doll.', '18': "I couldn't shake off the feeling that something was off about it.", '19': 'One night, I woke up to the sound of giggling coming from my bedroom.', '20': 'I slowly opened my eyes, and my heart stopped when I saw the doll standing at the foot of my bed, swaying back and forth.', '21': 'Its eyes seemed to be glowing in the darkness, and it had an eerie smile on its face.', '22': 'I was petrified, unable to move or make a sound.', '23': 'I blinked, and the doll was gone.', '24': 'I decided to confide in a friend, who suggested that I get rid of the doll.', '25': 'But every time I tried to dispose of it, it would mysteriously reappear in my house.', '26': 'It was as if the doll was determined to stay with me, and its presence was becoming increasingly malevolent.', '27': 'My once peaceful home had turned into a nightmare.', '28': 'I would hear footsteps in the middle of the night, and objects would move on their own.', '29': 'I would find the doll in unexpected places, staring at me with its unblinking eyes.', '30': 'I became sleep-deprived and paranoid, afraid to be alone in my own home.', '31': 'One night, during another stormy evening, I decided to confront the doll once and for all.', '32': 'I grabbed it with trembling hands and took it outside, determined to get rid of it for good.', '33': 'But as I was about to throw it into a nearby lake, the doll suddenly came alive in my arms.', '34': 'It laughed hysterically, its eyes glowing brighter than ever.', '35': 'In a panic, I dropped the doll and ran back to my house, slamming the door shut behind me.', '36': "But the doll wasn't done with me yet.", '37': 'It kept appearing and disappearing, taunting me with its eerie presence.', '38': "I couldn't take it anymore.", '39': 'Desperate, I sought help from a paranormal expert who came to investigate my home.', '40': 'But as soon as he laid eyes on the doll, he gasped and took a step back.', '41': 'He told me that the doll was cursed, possessed by a vengeful spirit.', '42': 'The paranormal expert warned me that the spirit attached to the doll was malevolent and had no intention of leaving.', '43': 'He explained that the doll had a dark history, having been used in occult rituals by a previous owner who had dabbled in black magic.', '44': 'The spirit had latched onto the doll and was now  ...

# %%
list_txt = read_txt(txt)
list_txt2 = read_txt(txt)
list_txt3 = read_txt(txt)

for lang in LANGUAGES:    
    for idx, y in enumerate(list_txt3):
        transl = translator.translate(y, src='en', dest=lang).text

# print array
""" print("[")
for i in list_txt:
    print(i)
print("]")  """
if ALLOW_CREATION:
    with open(f"./scripts/{PROJECT_NAME}.py", 'w') as f:
        f.write(f"{PROJECT_NAME} = {{  \n")
        f.write(f'"text_spoken": {{\n')  
        for index, i in enumerate(list_txt):
            f.write('"'+str(index)+'": "' + i + '"' + "," + '\n')
        f.write(f'}},\n')
        f.write(f'"image_generation": {{\n')   
        for index2, i2 in enumerate(list_txt2):
            r.extract_keywords_from_text(i2)
            keywords = r.get_ranked_phrases()
            temp_str = ""
            for y in keywords:
                temp_str = temp_str + y + ',' + " "
            temp_str = temp_str[:-2]
            f.write('"'+str(index2)+'": "' + temp_str + '"' + ","+ '\n')
        f.write(f'}},\n')
        f.write(f"}}\n")

# %%
# print summary
# Extracting the keywords by passing the text


# get the list of keywords
print("{")
for index2, i2 in enumerate(list_txt2):
    r.extract_keywords_from_text(i2)
    keywords = r.get_ranked_phrases()
    temp_str = ""
    for y in keywords:
        temp_str = temp_str + y + ',' + " "
    temp_str = temp_str[:-2]
    print('"'+str(index2)+'": "' + temp_str + '"' + ",")
print("}")
# Out:
# {
# "0": "old trinkets, late grandmother, sorting, passing, memories, cleaning, attic",
# "1": "antique doll hidden, stumbled upon, dusty boxes, small, rummaged, corner",
# "2": "curly golden hair, big blue eyes, stare right, porcelain skin, seemed",
# "3": "storm outside, chill ran, spine, picked, despite",
# "4": "strange sensation, watching, touched, soon, someone, felt, doll",
# "5": "imagination playing tricks, quickly brushed, shelf, placed, doll, bedroom",
# "6": "night went, watched, shake, feeling",
# "7": "strange noises coming, woke, night, bedroom",
# "8": "eyes wide open, tiptoed towards, heart skipped, doll sitting, source, sound, saw, floor, beat",
# "9": "sure, shelf, left",
# "10": "placed, picked, must, fallen, convinced, back, accidentally",
# "11": "things started, get even, following day, eerie",
# "12": "time, noticed, moved, foot, doll, bed",
# "13": "unease every time, started, sense, looked, got, feel, explain",
# "14": "storm outside continued, ominous atmosphere, rage, house, adding",
# "15": "movements became, days went, unpredictable, frequent, doll",
# "16": "living room one moment, would, next, hallway",
# "17": "feel paranoid, watched, started, doll, convinced",
# "18": "something, shake, feeling",
# "19": "one night, giggling coming, woke, sound, bedroom",
# "20": "swaying back, slowly opened, heart stopped, doll standing, saw, forth, foot, eyes, bed",
# "21": "eyes seemed, eerie smile, glowing, face, darkness",
# "22": "unable, sound, petrified, move, make",
# "23": "gone, doll, blinked",
# "24": "get rid, suggested, friend, doll, decided, confide",
# "25": "would mysteriously reappear, every time, tried, house, dispose",
# "26": "becoming increasingly malevolent, stay, presence, doll, determined",
# "27": "peaceful home, turned, nightmare",
# "28": "would hear footsteps, objects would move, night, middle",
# "29": "would find, unexpected places, unblinking eyes, staring, doll",
# "30": "became sleep, paranoid, home, deprived, alone, afraid",
# "31": "another stormy evening, one night, doll, decided, confront",
# "32": "trembling hands, get rid, took, outside, grabbed, good, determined",
# "33": "doll suddenly came alive, nearby lake, throw, arms",
# "34": "eyes glowing brighter, laughed hysterically, ever",
# "35": "door shut behind, ran back, slamming, panic, house, dropped, doll",
# "36": "yet, done, doll",
# "37": "kept appearing, eerie presence, taunting, disappearing",
# "38": "take, anymore",
# "39": "sought help, paranormal expert, investigate, home, desperate, came",
# "40": "step back, laid eyes, took, soon, gasped, doll",
# "41": "vengeful spirit, told, possessed, doll, cursed",
# "42": "paranormal expert warned, spirit attached, malevolent, leaving, intention, doll",
# "43": "previous owner, occult rituals, dark history, black magic, used, explained, doll, dabbled",
# "44": "seeking revenge, latched onto, spirit, doll",
# "45": "doll remained unresponsive, expert performed, cleansing ritual, doll, trying, spirit, banish",
# "46": "home grew even, eerie whispers echoing, doors slamming shut, lights flickering, sinister, halls, atmosphere",
# "47": "malevolent presence lurking around every corner, constant fear, living, feeling, doll",
# "48": "one fateful night, scratching coming, bedroom door, woke, sound",
# "49": "slowly opened, otherworldly intensity, eyes glowing, doll sitting, room, mustered, middle, find, door, courage",
# "50": "tried, strength, mustered, ignore, heart, gripped, fear, doll, confront",
# "51": "voice shaky, want, demanded",
# "52": "sinister grin, expression twisted, voice, spoke, doll",
# "53": "sending chills, cannot escape, spine, hissed",
# "54": "never leave",
# "55": "haunting presence, terror, rid, ran, house, grabbed, fit, doll, determined",
# "56": "remote cliff overlooking, reached, ocean, hours, drove",
# "57": "tears streaming, dark waters, crashing waves, watching, threw, face, doll, disappeared",
# "58": "heard laughter echoing, wind, turned, leave",
# "59": "somehow standing, looked back, glowing eyes, staring, see, doll, cliff",
# "60": "blood turned, torment, spirit, returned, realized, ice, doll, banished",
# "61": "never looked back, sheer panic, state, fled, cliff",
# "62": "moved far away, way back, always find, seemed, hoping, grasp, escape, doll",
# "63": "would appear next, haunting presence continued, perpetual fear, always looking, wondering, torment, shoulder, lived, dreams, doll",
# "64": "still plagued, malevolent spirit, doll, day",
# "65": "tried everything, seems, rid, presence, nothing, hold, break",
# "66": "laughter still echoes, constant reminder, nightmares, horror, experienced, doll",
# "67": "life horror story, present reminder, haunted doll, life, doll, unfolded, real, part, grandmother, found, ever, come, attic, accept",
# }
