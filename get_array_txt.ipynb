# %%
import numpy as np
from rake_nltk import Rake
import nltk
nltk.download('stopwords')
import os
import googletrans
from googletrans import Translator



LANGUAGES = ['pt','fr','de','hi','it','ja','es','id']
translator = Translator()


#IMPORTANT!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
ALLOW_CREATION = False
PROJECT_NAME = 'tips_warren'

obj_r = {
    "couldn´t": "could not",
    "I'm": "I am",
    "I'll": "I will",
    "can't": "cannot",
    "It's": "It is",
    "We're": "We are",
    "we're": "we are",
    "we'll": 'we will',
    "you're": "you are"
}

banned_words = ["shadowy"]

replace_words = [
    ['"',""],
    ['’',"'"],
    ["!","."],
    [":","."],
    [" - ",", "]
]

def replace_text(str_input,obt_replace):
    
    for key in obt_replace:        
        str_input = str_input.replace(key,obt_replace[key])
    return str_input

def read_txt(txt):
    text_splited = []
    for y in replace_words:
            txt = txt.replace(y[0], y[1])
    """ txt = txt.replace("!",".")
    txt = txt.replace(":",".") # verify after """
    text_split = " ".join(txt.split()).split(".")
    first = text_split[0]
    temp_str = ""    
    
    for i in reversed(text_split):

        
                
        if i == first:            
            text_splited.append(replace_text(i + temp_str,obj_r) + ".")
        elif(i != " " and i != ""):            
            if(i[0].startswith(" ")):
                temp = i + temp_str + "."
                temp = temp[1:]       
                text_splited.append(replace_text(temp,obj_r))
                temp_str = ""
            else:                
                temp_str = i + temp_str 
    return reversed(text_splited)



txt = """
Hello everyone and welcome to another episode of Insightful Freedom! Today, we're going to delve into the world of investing and take a closer look at some of the tips and tricks used by the world's greatest investor, Warren Buffett. Whether you're a seasoned investor or just starting out, these tips are sure to help you make more informed investment decisions and achieve financial freedom. So, without further ado, let's get started!

Tip number 1, invest in what you know: This tip is all about investing in industries and companies that you understand and have knowledge about. By focusing on areas that you're familiar with, you'll be able to better assess the potential for growth and understand the risks involved. Warren Buffett has made a fortune by investing in consumer goods, retail, and insurance, among others. He believes in investing in industries and companies that he knows and uses himself. By following this principle, you'll be more confident in your investment decisions and have a better understanding of the risks and rewards involved.

Tip number 2, patience is key: One of the keys to successful investing is having patience. Don't try to time the market or make quick trades. Instead, focus on long-term investments and hold onto them. This approach can help you avoid the short-term volatility of the market and gives your investments more time to grow and compound. Warren Buffett is famous for his buy-and-hold approach, where he invests in companies for the long-term and doesn't engage in frequent buying and selling. By having patience, you can also avoid the emotional rollercoaster of short-term market movements and focus on the long-term potential of your investments.

Tip number 3, look for undervalued opportunities: Another key to successful investing is finding good companies that are currently undervalued and have a lot of potential for growth. By investing in undervalued companies, you'll be able to buy more shares for your money, which can result in larger returns over time. Warren Buffett is known for his value investing approach, where he looks for companies that are undervalued compared to their intrinsic value. He believes that by investing in these companies, he can take advantage of the market's mispricing and generate substantial returns over the long term.

Tip number 4, avoid debt: Warren Buffett is famous for his aversion to debt, and this is something you should also consider in your investments. Debt can increase the risk of your investments and make it more difficult for you to weather market downturns. Instead, focus on investing in companies with strong balance sheets and a low level of debt. This way, you'll be able to better manage the risk involved in your investments and potentially increase your returns over time.

Tip number 5, diversify your portfolio: Diversification is a crucial component of successful investing. Don't put all your eggs in one basket. Spread your investments across different industries and companies to minimize risk. This way, if one investment performs poorly, the others can help offset the loss. Diversification can help you manage risk and potentially increase your overall returns. Warren Buffett is a big advocate of diversification, and he encourages investors to spread their investments across a variety of different companies and industries to minimize risk.

Tip number 6, read annual reports: One of the best ways to get to know the companies you're investing in is by reading their annual reports and financial statements. This can give you valuable insights into the company's financial health, growth prospects, and risk factors. By reading annual reports, you can also get a better understanding of how a company is run and how its management views the future. This information can be extremely valuable when making investment decisions, and it's something that Warren Buffett has used to great effect throughout his career.

Tip number 7, don't follow the herd: One of the biggest mistakes that investors make is following the crowd and making investment decisions based on what others are doing or what's popular. Instead, do your own research and make decisions based on your own analysis. Warren Buffett believes in going against the crowd and investing in undervalued companies that the market may be overlooking. By following your own research and analysis, you'll be less likely to make mistakes based on market trends or fads and more likely to make informed investment decisions that are right for you.

Tip number 8, ignore short-term market movements: The stock market can be volatile in the short-term, but this shouldn't affect your long-term investment strategy. Don't make decisions based on short-term market movements, as this can lead to emotional investing and potentially costly mistakes. Instead, focus on the long-term potential of your investments and ignore the noise of short-term market movements. Warren Buffett has always emphasized the importance of focusing on the long-term and ignoring short-term market fluctuations. By doing this, you'll be able to make more informed investment decisions and avoid costly mistakes.

Tip number 9, invest in companies with strong management: The management of a company can have a huge impact on its success or failure. Invest in companies with strong, competent, and ethical management teams. Look for companies with leaders who have a track record of success, a clear vision for the future, and a commitment to their shareholders. Warren Buffett has always placed a great emphasis on the importance of management, and he looks for companies with strong leadership when making investment decisions. By investing in companies with strong management teams, you'll be more likely to see growth and success in your investments.

Tip number 10, have a long-term investment strategy: One of the keys to successful investing is having a long-term investment strategy in place. Decide what your investment goals are and create a plan to achieve them. This can help you avoid making impulsive decisions based on short-term market movements and ensure that you're making informed decisions that align with your long-term goals. Warren Buffett has always had a clear investment strategy, and he's stuck to it over the years, even though market downturns. By having a long-term investment strategy, you'll be more likely to achieve your investment goals and build a successful portfolio over time.
And there you have it, folks - 10 tips from Warren Buffett on how to be a successful investor. Remember, investing is a long-term game, so be patient, do your research, and stick to your investment strategy. With these tips in mind, you'll be on your way to achieving financial freedom in no time.
Thanks for tuning in to another episode of Insightful Freedom! Join us next week for more valuable insights and tips on achieving financial freedom. Until then, happy investing!







"""


# Creating an instance
r = Rake()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Matheus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
list_txt = read_txt(txt)
list_txt2 = read_txt(txt)
list_txt3 = read_txt(txt)

for lang in LANGUAGES:    
    for idx, y in enumerate(list_txt3):
        transl = translator.translate(y, src='en', dest=lang).text

# print array
""" print("[")
for i in list_txt:
    print(i)
print("]")  """
if ALLOW_CREATION:
    with open(f"./scripts/{PROJECT_NAME}.py", 'w') as f:
        f.write(f"{PROJECT_NAME} = {{  \n")
        f.write(f'"text_spoken": {{\n')  
        for index, i in enumerate(list_txt):
            f.write('"'+str(index)+'": "' + i + '"' + "," + '\n')
        f.write(f'}},\n')
        f.write(f'"image_generation": {{\n')   
        for index2, i2 in enumerate(list_txt2):
            r.extract_keywords_from_text(i2)
            keywords = r.get_ranked_phrases()
            temp_str = ""
            for y in keywords:
                temp_str = temp_str + y + ',' + " "
            temp_str = temp_str[:-2]
            f.write('"'+str(index2)+'": "' + temp_str + '"' + ","+ '\n')
        f.write(f'}},\n')
        f.write(f"}}\n")

# %%
# print summary
# Extracting the keywords by passing the text


# get the list of keywords
print("{")
for index2, i2 in enumerate(list_txt2):
    r.extract_keywords_from_text(i2)
    keywords = r.get_ranked_phrases()
    temp_str = ""
    for y in keywords:
        temp_str = temp_str + y + ',' + " "
    temp_str = temp_str[:-2]
    print('"'+str(index2)+'": "' + temp_str + '"' + ",")
print("}")
# Out:
# {
# }
